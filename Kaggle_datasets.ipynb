# %% [markdown]
# <a href="https://colab.research.google.com/github/avdlaan/Angular-10-Templates/blob/master/Kaggle_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d allen-institute-for-ai/CORD-19-research-challenge
# Out:
# ...
# 100% 12.1G/12.1G [04:35<00:00, 60.9MB/s]
# 100% 12.1G/12.1G [04:35<00:00, 47.1MB/s]

# %%
! cd /content

# %%
mkdir train

# %%
# !unzip /content/CORD-19-research-challenge.zip -d /content/train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/train/document_parses/pmc_json/PMC7121890.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121892.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121893.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121897.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121898.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121899.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121901.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121902.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121904.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121907.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121909.xml.json
#   inflating: /content/train/document_parses/pmc_json/PMC7121911.xml.json
# ...
