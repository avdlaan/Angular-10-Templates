# %% [markdown]
# <a href="https://colab.research.google.com/github/avdlaan/Angular-10-Templates/blob/master/Answer_Extractor_functions_from_Data_set_with_Ktrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip3 install ktrain==0.28.2
# !pip install tensorflow==2.4.1

# %%
import numpy as np
import pandas as pd 
import glob
import json
import math

# %% [markdown]
# Set the initial imports- for the next step let us iterate the directory.

# %%
all_json = glob.glob('/content/drive/MyDrive/train/document_parses/json_test/*.json', recursive=True)

# let us get the list of articles
len(all_json)
print(len(all_json))
# Out:
# 39

# %%
class FileReader:
    def __init__(self, file_path):
        with open(file_path) as file:
            content = json.load(file)
            self.paper_id = content['paper_id']
            self.abstract = []
            self.body_text = []
            # Abstract
            for entry in content['abstract']:
                self.abstract.append(entry['text'])
            # Body text
            for entry in content['body_text']:
                self.body_text.append(entry['text'])
            self.abstract = '\n'.join(self.abstract)
            self.body_text = '\n'.join(self.body_text)
    def __repr__(self):
        return f'{self.paper_id}: {self.abstract[:400]}... {self.body_text[:500]}...'

# %%
first_row = FileReader(all_json[0])
print(first_row)
# Out:
# 000a0fc8bbef80410199e690191dc3076a290117: Background: Various transcription factors are involved in the process of mutually exclusive expression and clonal variation of the Plasmodium multigene (var) family. Recent studies revealed that a P. falciparum SWI/SNF-related matrix-associated actin-dependent regulator of chromatin (PfSWIB) might trigger stage-specific programmed cell death (PCD), and was not only crucial for the survival and dev... Plasmodium falciparum, which causes malignant malaria such as cerebral malaria (CM) or pregnancy-associated malaria (PAM) [1, 2] , is the cause of death to 435,000 individuals annually [3] . Plasmodium falciparum erythrocyte membrane protein 1 (PfEMP1), which is encoded by the var gene family comprising approximately 60 members, is the major virulence factor involved in the antigenic variation and clinical pathogenicity of falciparum malaria [4, 5] . It is remarkable that the expression of var f...

# %%
dict_ = {'paper_id': [], 'abstract': [], 'body_text': []}
for idx, entry in enumerate(all_json):
    try:
        content = FileReader(entry)
        if (idx % 1000 == 0):
            print(f"processing {idx} of {len(all_json)} ")
        dict_['paper_id'].append(content.paper_id)
        dict_['abstract'].append(content.abstract)
        dict_['body_text'].append(content.body_text)
    except:
        pass
df_covid = pd.DataFrame(dict_, columns=['paper_id', 'abstract', 'body_text'])
df_covid.head(39)
# Out:
# processing 0 of 39
#                                     paper_id  ...                                          body_text
# 0   000a0fc8bbef80410199e690191dc3076a290117  ...  Plasmodium falciparum, which causes malignant ...
# 1   00a0df94d685622b8a7894f6a952e97a7e89ccf6  ...  Recovery of muscle tissue damaged by diseases ...
# 2   00a00d0edc750db4a0c299dd1ec0c6871f5a4f24  ...  This is an Open Access article distributed und...
# 3   00a1a921b93d9773f46d21ac22b1363371c7d535  ...  a1111111111 a1111111111 a1111111111 a111111111...
# 4   00a0ab182dc01b6c2e737dfae585f050dcf9a7a5  ...  The world was made aware of a newly discovered...
# 5   00a0c02539f89317beb2954f72b20fa91dd0cc87  ...  On 23 March 2020, the UK announced the "stay a...
# 6   0a0c7465fb4d6dfc7c5c3b4d019bf12a9a3cea6b  ...  The global pandemic caused by the coronavirus ...
# 7   0a1a319ffd87d5b69e7738e57c382a3fc3c8b420  ...  In December 2019, the severe acute respiratory...
# 8   0a00fe902ce5f523ceca3d01dc68dd1ddaac253b  ...  On behalf of all authors, the corresponding au...
# 9   0a0d9d7f7ccd750820cbe07415db17e4d8ae2f2d  ...  To respond effectively to the recent Severe Ac...
# 10  0a0b0673e5c09379855c22e73db193cad1c70a39  ...  How does body posture influence the way we int...
# 11  0a1a2041b8dbefa5d83aecb2a0e0f820e7a54f26  ...  The implementation of extreme measures of soci...
# 12  0a0a7434df071b9842df9d65ed293b122b275227  ...  Since November 2019, the severe acute respirat...
# 13  0a0e6c7c4e126e2f01da6c716cfcd59b395411d9  ...  We have read with great interest several recen...
# 14  0a0af20f552c58dd3d3b0f9d937d7648ba59f7fc  ...  As the spread of COVID-19 continues around the...
# 15  0a1ad2593dec298e6d75d424e4ace0be1fb4ea70  ...  The coronavirus disease 2019 (COVID- 19) pande...
# 16  0a1b82c91b160fccbd9874970aed6095ad2709fc  ...  The severe acute respiratory syndrome coronavi...
# 17  0a0e2725bfbe62c2b949a27e492595c23a2f483e  ...  Medical students often cite career advising as...
# 18  0a0ffa864d11abd4a2be59d03ad75c961ba5d51d  ...  Each year, millions of people are exposed to s...
# 19  0a0cbd4cb08c862deadcb5aaef22a27b770c0791  ...  Respiratory viruses are common causes of human...
# 20  0a0c68e588b799a72584f3974267f7db451217ed  ...  There is an ongoing pandemic of coronavirus di...
# 21  0a0b578e9257a8dbde2767c0a00c0608814158ef  ...  Uncontrolled bleeding is the most common cause...
# 22  0a0b130a7ef02117ec87232801b56f97be2540b7  ...  In the Republic of Ireland, maternity services...
# 23  0a0bc6bc993e37df9be46a2c80e969cbac5a89db  ...  Feline infectious peritonitis virus (FIPV) is ...
# 24  0a0edd03229d5fc4c06c3da09970418150c2b5ac  ...  Since January of 2020, the novel coronavirus (...
# 25  0a0afb5dc02afa81689e0e75afe2f9a21ce09e70  ...  4. The role of ubiquitination and the proteins...
# 26  0a1abc458accfcceb47f047357f06b4a86fddcbe  ...  Data are limited about severe acute respirator...
# 27  0a1a05f3e2c7d08b199778a88abf31af313b16bc  ...  Severe acute respiratory syndrome coronavirus ...
# 28  0a0f64ff0a69e3f2d878fab95559d3b891f98cd1  ...  A secular decline in entrepreneurial activity ...
# 29  0a1b57b58a4f85beb910c49de95a52fd2b15096e  ...  2009 will be remembered as the year of pandemi...
# 30  0a0b6b0607747394ea7757cc6fbd415b7d025b30  ...  The World Health Organization (WHO) declared C...
# 31  0a1a272f7e9c0ee44a61681181f3d5d2e36571ee  ...  Air pollution is a major environmental issue t...
# 32  0a1a26855aab1c04db731b54a25ac7108bd49884  ...  A population can be immune to epidemics even i...
# 33  0a1b2df70c2ceb9154c2e3b36fde9236f873b060  ...  The coronavirus disease 2019 (Covid-19) pandem...
# 34  0a1a4738f2451675e376614392a56618d1c7935c  ...  interventions used. According to Chinese autho...
# 35  0a00a6df208e068e7aa369fb94641434ea0e6070  ...  Bacille Calmette-Guérin (BCG) is an attenuated...
# 36  0a1ae4a01ce462e94e03b9e7dde852a2e8371d86  ...  Prurigo pigmentosa (PP) is a skin disease char...
# 37  0a00b5590b5455dcedb19fc1be5925de48692a9d  ...  In March 2020, the World Health Organization (...
# 38  0a00a6df208e068e7aa369fb94641434ea0e6070  ...  Bacille Calmette-Guérin (BCG) is an attenuated...
#
# [39 rows x 3 columns]

# %%
import ktrain
from ktrain.text.qa import AnswerExtractor

ae = AnswerExtractor()

df_covid = ae.extract(df_covid.body_text.values, df_covid, [('What are the proteins in Covid Virus?', 'Proteins'),
                                     ('Effects of Covid?','Effects'),('What the Covid Virus Strains?','Strains')])

df_covid.head(39)
# Out:
# Downloading:   0%|          | 0.00/443 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/536M [00:00<?, ?B/s]
#                                     paper_id  ...                  Strains
# 0   000a0fc8bbef80410199e690191dc3076a290117  ...                     None
# 1   00a0df94d685622b8a7894f6a952e97a7e89ccf6  ...                     None
# 2   00a00d0edc750db4a0c299dd1ec0c6871f5a4f24  ...                     None
# 3   00a1a921b93d9773f46d21ac22b1363371c7d535  ...                     None
# 4   00a0ab182dc01b6c2e737dfae585f050dcf9a7a5  ...                     None
# 5   00a0c02539f89317beb2954f72b20fa91dd0cc87  ...                     None
# 6   0a0c7465fb4d6dfc7c5c3b4d019bf12a9a3cea6b  ...                     None
# 7   0a1a319ffd87d5b69e7738e57c382a3fc3c8b420  ...                     None
# 8   0a00fe902ce5f523ceca3d01dc68dd1ddaac253b  ...                     None
# 9   0a0d9d7f7ccd750820cbe07415db17e4d8ae2f2d  ...                     None
# 10  0a0b0673e5c09379855c22e73db193cad1c70a39  ...                     None
# 11  0a1a2041b8dbefa5d83aecb2a0e0f820e7a54f26  ...                     None
# 12  0a0a7434df071b9842df9d65ed293b122b275227  ...  SARS 2002 and MERS 2012
# 13  0a0e6c7c4e126e2f01da6c716cfcd59b395411d9  ...                     None
# 14  0a0af20f552c58dd3d3b0f9d937d7648ba59f7fc  ...                     None
# 15  0a1ad2593dec298e6d75d424e4ace0be1fb4ea70  ...                     None
# 16  0a1b82c91b160fccbd9874970aed6095ad2709fc  ...                     None
# 17  0a0e2725bfbe62c2b949a27e492595c23a2f483e  ...                     None
# 18  0a0ffa864d11abd4a2be59d03ad75c961ba5d51d  ...                     None
# 19  0a0cbd4cb08c862deadcb5aaef22a27b770c0791  ...                     None
# 20  0a0c68e588b799a72584f3974267f7db451217ed  ...                     None
# 21  0a0b578e9257a8dbde2767c0a00c0608814158ef  ...                     None
# 22  0a0b130a7ef02117ec87232801b56f97be2540b7  ...                     None
# 23  0a0bc6bc993e37df9be46a2c80e969cbac5a89db  ...                     None
# 24  0a0edd03229d5fc4c06c3da09970418150c2b5ac  ...                     None
# 25  0a0afb5dc02afa81689e0e75afe2f9a21ce09e70  ...                     None
# 26  0a1abc458accfcceb47f047357f06b4a86fddcbe  ...                     None
# 27  0a1a05f3e2c7d08b199778a88abf31af313b16bc  ...                     None
# 28  0a0f64ff0a69e3f2d878fab95559d3b891f98cd1  ...                     None
# 29  0a1b57b58a4f85beb910c49de95a52fd2b15096e  ...                     None
# 30  0a0b6b0607747394ea7757cc6fbd415b7d025b30  ...                     None
# 31  0a1a272f7e9c0ee44a61681181f3d5d2e36571ee  ...                     None
# 32  0a1a26855aab1c04db731b54a25ac7108bd49884  ...                     None
# 33  0a1b2df70c2ceb9154c2e3b36fde9236f873b060  ...                     None
# 34  0a1a4738f2451675e376614392a56618d1c7935c  ...                     None
# 35  0a00a6df208e068e7aa369fb94641434ea0e6070  ...                     None
# 36  0a1ae4a01ce462e94e03b9e7dde852a2e8371d86  ...                     None
# 37  0a00b5590b5455dcedb19fc1be5925de48692a9d  ...                     None
# 38  0a00a6df208e068e7aa369fb94641434ea0e6070  ...                     None
#
# [39 rows x 6 columns]

# %%
#df_covid = ae.extract(df_covid.body_text.values, df_covid, [('Covid Recovery?', 'Recovery'),
#                                     ('Long Covid signs?','Signs')])
#df_covid.head(12)
